# %%
# Dependencies
import requests
import json
import pandas as pd
api_key = '2d1f68e5967dae99d0a209f6bd7c44e1'

# %%
params= {
    'api_key': api_key,
    'file_type': 'json',
    'tag_names': 'loans'
}

# Build URL using the geocode endpoint
base_url = "https://api.stlouisfed.org/fred"
data_source = 'tags/series'
url = f'{base_url}/{data_source}'
url
# Out:
# 'https://api.stlouisfed.org/fred/tags/series'

# %%
response = requests.get(url, params=params)
data = json.loads(response.content.decode('utf-8'))
data
# Out:
# {'realtime_start': '2025-01-27',
#  'realtime_end': '2025-01-27',
#  'order_by': 'series_id',
#  'sort_order': 'asc',
#  'count': 10918,
#  'offset': 0,
#  'limit': 1000,
#  'seriess': [{'id': 'A030RC1A027NBEA',
#    'realtime_start': '2025-01-27',
#    'realtime_end': '2025-01-27',
#    'title': 'Net lending or net borrowing (-), NIPAs: Government: Statistical discrepancy',
#    'observation_start': '1929-01-01',
#    'observation_end': '2023-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Billions of Dollars',
#    'units_short': 'Bil. of $',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2024-09-26 07:51:11-05',
#    'popularity': 1,
#    'group_popularity': 3,
#    'notes': 'BEA Account Code: A030RC\n\nFor more information about this series, please see http://www.bea.gov/national/.'},
#   {'id': 'A030RC1Q027SBEA',
#    'realtime_start': '2025-01-27',
# ...

# %%
df = pd.DataFrame(data['seriess'])
df.head()
# Out:
#                 id realtime_start realtime_end  \
# 0  A030RC1A027NBEA     2025-01-27   2025-01-27
# 1  A030RC1Q027SBEA     2025-01-27   2025-01-27
# 2  A928RC1A027NBEA     2025-01-27   2025-01-27
# 3  A928RC1Q027SBEA     2025-01-27   2025-01-27
# 4     ABWFCSMMFXDC     2025-01-27   2025-01-27
#
#                                                title observation_start  \
# 0  Net lending or net borrowing (-), NIPAs: Gover...        1929-01-01
# 1  Net lending or net borrowing (-), NIPAs: Gover...        1947-01-01
# 2  Gross domestic investment, capital account tra...        1929-01-01
# 3  Gross domestic investment, capital account tra...        1947-01-01
# 4  Use of Financial Services, Assets: Outstanding...        2006-01-01
#
#   observation_end  frequency frequency_short                units  \
# 0      2023-01-01     Annual               A  Billions of Dollars
# 1      2024-07-01  Quarterly               Q  Billions of Dollars
# ...

# %%
df.to_csv('Resources/loan_data.csv')
